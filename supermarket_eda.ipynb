# %% [markdown]
# #description/problem statement

# %% [markdown]
# ## workflow :
# - step 1 : importing the required libaries
# - loading the data
# - basic understanding of data
# - preprocessing of data

# %% [markdown]
# ## import the required libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## loading Dataset

# %%
df=pd.read_csv("D:\\python_core\\data sets\\supermarket_sales - Sheet1.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## checking the shape of data

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# ## preview of data

# %%
df.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 413  696-90-2548      A    Yangon        Normal    Male
# 54   242-55-6721      B  Mandalay        Normal    Male
# 785  404-91-5964      A    Yangon        Normal    Male
# 270  783-09-1637      B  Mandalay        Normal  Female
# 834  427-45-9297      B  Mandalay        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 413       Sports and travel       25.84         3   3.8760   81.3960
# 54       Home and lifestyle       16.16         2   1.6160   33.9360
# 785  Electronic accessories       74.58         7  26.1030  548.1630
# 270       Sports and travel       67.43         5  16.8575  354.0075
# 834      Home and lifestyle       40.73         7  14.2555  299.3655
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 413  3/10/2019  18:55      Ewallet   77.52                 4.761905
# 54    3/7/2019  11:49      Ewallet   32.32                 4.761905
# ...

# %% [markdown]
# ## fetching columns name and description about the data

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
#  ##### - Attributes Information
# - Invoice id: Computer generated sales slip invoice identification number
#
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# - City: Location of supercenters
#
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# - Gender: Gender type of customer
#
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in $
#
# - Quantity: Number of products purchased by customer
#
# - Tax: 5% tax fee for customer buying
#
# - Total: Total price including tax
#
# - Date: Date of purchase (Record available from January 2019 to March 2019)
#
# - Time: Purchase time (10am to 9pm)
#
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# - COGS: Cost of goods sold
#
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ## basic information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ### here  invoice col irrelevant so we drop so we drop it and date , time columns had wrong datatype so we have to change into datetime format

# %%
df.drop(columns=['Invoice ID'],inplace=True)

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date   Time      Payment    cogs  \
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash   76.40
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["Time"]=pd.to_datetime(df["Time"])

# %%
df.dtypes
# Out:
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# ## step 3: preprocessing of the data (data rangling)

# %% [markdown]
# ## 3.1 checking missing value in the data

# %%
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ### from above output we can say that is no missing value in my data

# %% [markdown]
# ## 3.2 checking the duplicay in tha data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### there is no duplicay in my data

# %% [markdown]
# ## 3.3 checking the unique value in the data

# %%
for i in df.columns:
    print(i,"--------",df[i].unique(),"     ",df[i].nunique())
# Out:
# Branch -------- ['A' 'C' 'B']       3
# City -------- ['Yangon' 'Naypyitaw' 'Mandalay']       3
# Customer type -------- ['Member' 'Normal']       2
# Gender -------- ['Female' 'Male']       2
# Product line -------- ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']       6
# Unit price -------- [74.69 15.28 46.33 58.22 86.31 85.39 68.84 73.56 36.26 54.84 14.48 25.51
#  46.95 43.19 71.38 93.72 68.93 72.61 54.67 40.3  86.04 87.98 33.2  34.56
#  88.63 52.59 33.52 87.67 88.36 24.89 94.13 78.07 83.78 96.58 99.42 68.12
#  62.62 60.88 54.92 30.12 86.72 56.11 69.12 98.7  15.37 93.96 56.69 20.01
#  18.93 82.63 91.4  44.59 17.87 15.43 16.16 85.98 44.34 89.6  72.35 30.61
#  24.74 55.73 55.07 15.81 75.74 15.87 33.47 97.61 78.77 18.33 89.48 62.12
#  48.52 75.91 74.67 41.65 49.04 78.31 20.38 99.19 96.68 19.25 80.36 48.91
#  83.06 76.52 49.38 42.47 76.99 47.38 44.86 21.98 64.36 89.75 97.16 87.87
# ...

# %% [markdown]
# ### 3.4 feature engineeering
# - year
# - month-name
# - day-name
# - day-numeric
# - hour
# - describe
# - correlation

# %%
from datetime import datetime as dt
#df["starting_year"]=df[Date].dt.year

# %%
df["year"]=df.Date.dt.year

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-05-19 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-05-19 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-05-19 13:23:00  Credit card
# 3         8  23.2880  489.0480 2019-01-27 2023-05-19 20:33:00      Ewallet
# 4         7  30.2085  634.3785 2019-02-08 2023-05-19 10:37:00      Ewallet
#
# ...

# %%
df["day_name"]=df.Date.dt.day_name()
df["month_name"]=df.Date.dt.month_name()
df["day"]=df.Date.dt.day

# %%
df.head(3)
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-05-19 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-05-19 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-05-19 13:23:00  Credit card
#
#      cogs  gross margin percentage  gross income  Rating  year  day_name  \
# 0  522.83                 4.761905       26.1415     9.1  2019  Saturday
# 1   76.40                 4.761905        3.8200     9.6  2019    Friday
# 2  324.31                 4.761905       16.2155     7.4  2019    Sunday
#
#   month_name  day
# 0    January    5
# ...

# %%
df["hour"]=df.Time.dt.hour
df["hour"]
# Out:
# 0      13
# 1      10
# 2      13
# 3      20
# 4      10
#        ..
# 995    13
# 996    17
# 997    13
# 998    15
# 999    13
# Name: hour, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date  ...      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05  ...      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08  ...         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  ...  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27  ...      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08  ...      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  year  day_name month_name  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.describe().T ## it gives the stastical value of the data
# Out:
#                           count         mean           std          min  \
# Unit price               1000.0    55.672130  2.649463e+01    10.080000
# Quantity                 1000.0     5.510000  2.923431e+00     1.000000
# Tax 5%                   1000.0    15.379369  1.170883e+01     0.508500
# Total                    1000.0   322.966749  2.458853e+02    10.678500
# cogs                     1000.0   307.587380  2.341765e+02    10.170000
# gross margin percentage  1000.0     4.761905  6.131498e-14     4.761905
# gross income             1000.0    15.379369  1.170883e+01     0.508500
# Rating                   1000.0     6.972700  1.718580e+00     4.000000
# year                     1000.0  2019.000000  0.000000e+00  2019.000000
# day                      1000.0    15.256000  8.693563e+00     1.000000
# hour                     1000.0    14.910000  3.186857e+00    10.000000
#
#                                  25%          50%          75%          max
# ...

# %%
df.describe(include="object").T
# Out:
#               count unique                  top freq
# Branch         1000      3                    A  340
# City           1000      3               Yangon  340
# Customer type  1000      2               Member  501
# Gender         1000      2               Female  501
# Product line   1000      6  Fashion accessories  178
# Payment        1000      3              Ewallet  345
# day_name       1000      7             Saturday  164
# month_name     1000      3              January  352

# %% [markdown]
# ## detecting outliers in the data

# %% [markdown]
# ### find out the numeric column for boxplot

# %%
df.dtypes
# Out:
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# year                                int64
# day_name                           object
# month_name                         object
# day                                 int64
# hour                                int64
# dtype: object

# %%
#from above we can see that there is a need to detect the outliers of only 4 columns
l=["Unit price","Quantity","Tax 5%","cogs","gross income","Rating","Total"]
plt.figure(figsize=(14,15))
pos=1
for i in l:
    plt.subplot(3,3,pos)
    sns.boxplot(x=i,data=df)
    pos=pos+1

# %% [markdown]
# ## correlation

# %%
df.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# year                            NaN       NaN       NaN       NaN       NaN
# day                        0.057021 -0.043347 -0.002515 -0.002515 -0.002515
# hour                       0.008242 -0.007317 -0.002770 -0.002770 -0.002770
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
there is a strong postivie correlation cogs,tax,gross income and total
so from the businesss point of view i will consider either total or gross income

# %% [markdown]
# ## step 3: insights

# %% [markdown]
#  ## the total sale of the super market

# %%
df["Total"].sum()
# Out:
# 322966.749

# %% [markdown]
# ## total sale of each branch

# %%
df.head(3)
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-05-19 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-05-19 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-05-19 13:23:00  Credit card
#
#      cogs  gross margin percentage  gross income  Rating  year  day_name  \
# 0  522.83                 4.761905       26.1415     9.1  2019  Saturday
# 1   76.40                 4.761905        3.8200     9.6  2019    Friday
# 2  324.31                 4.761905       16.2155     7.4  2019    Sunday
#
#   month_name  day  hour
# 0    January    5    13
# ...

# %%
t=df.groupby(["City","Branch"])["Total"].agg(["sum"])
t1=t.reset_index()
t1
# Out:
#         City Branch          sum
# 0   Mandalay      B  106197.6720
# 1  Naypyitaw      C  110568.7065
# 2     Yangon      A  106200.3705

# %%
plt.pie(x=t1["sum"],labels=t1["Branch"],autopct="%.2f%%");

# %% [markdown]
# ### from city or branch we can consider one of its thats is branch

# %%
since c branch has maximum sale so we would explore the c branch more

# %%
sns.barplot(x="Branch",y="Total",estimator=sum,data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %% [markdown]
# ### on which date maximum sale was recorded and what was the product category of that day

# %%
df_c=df[df["Branch"]=="C"]
df_c
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 5        C  Naypyitaw        Normal    Male  Electronic accessories
# 7        C  Naypyitaw        Normal  Female      Home and lifestyle
# 20       C  Naypyitaw        Member    Male  Electronic accessories
# 34       C  Naypyitaw        Member  Female      Food and beverages
# ..     ...        ...           ...     ...                     ...
# 983      C  Naypyitaw        Normal    Male       Health and beauty
# 984      C  Naypyitaw        Normal    Male  Electronic accessories
# 988      C  Naypyitaw        Member    Male  Electronic accessories
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date                Time  \
# ...

# %%
df_c[df_c["Total"]==df_c["Total"].max()]
# Out:
#     Branch       City Customer type  Gender         Product line  Unit price  \
# 350      C  Naypyitaw        Member  Female  Fashion accessories        99.3
#
#      Quantity  Tax 5%    Total       Date                Time      Payment  \
# 350        10   49.65  1042.65 2019-02-15 2023-05-19 14:53:00  Credit card
#
#       cogs  gross margin percentage  gross income  Rating  year day_name  \
# 350  993.0                 4.761905         49.65     6.6  2019   Friday
#
#     month_name  day  hour
# 350   February   15    14

# %% [markdown]
# ## hot selling month of the company

# %%
sns.barplot(x="Total",y="month_name",data=df)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
sns.barplot(x="Branch",y="Total",data=df)
plt.title("average sale of each branch")
plt.subplot(1,2,2)
sns.barplot(x="Branch",y="Total",data=df,estimator=sum)
plt.title("total sale of each branch")
# Out:
# Text(0.5, 1.0, 'total sale of each branch')

# %%
from this we can say that feburary was considered as off season so we implement si discounted policy or happy hours scheme at

# %% [markdown]
# ## hot selling month of each branch

# %%
sns.barplot(x="Total",y="Branch",data=df,estimator=sum,hue="month_name");

# %% [markdown]
# ## Total sale on weekdays and weekends

# %%
df["weekdays/weekends"]=df["day_name"].apply(lambda x: "weekends" if ((x=="Saturday") | (x=="Sunday")) else "weekdays")
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-05-19 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-05-19 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-05-19 13:23:00  Credit card
# 3         8  23.2880  489.0480 2019-01-27 2023-05-19 20:33:00      Ewallet
# 4         7  30.2085  634.3785 2019-02-08 2023-05-19 10:37:00      Ewallet
#
# ...

# %%
df.groupby(["weekdays/weekends"])["Total"].sum()
# Out:
# weekdays/weekends
# weekdays    222388.047
# weekends    100578.702
# Name: Total, dtype: float64

# %%
sns.barplot(x="Total",y="weekdays/weekends",data=df,estimator=sum)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='weekdays/weekends'>

# %%
this show that on weekdays sale was than more sale as compare to weekends

# %% [markdown]
# ## find out the total weekday and weekend sell of all branches

# %%
df.groupby(["Branch","weekdays/weekends"])["Total"].sum()
# Out:
# Branch  weekdays/weekends
# A       weekdays             72428.1390
#         weekends             33772.2315
# B       weekdays             74497.9200
#         weekends             31699.7520
# C       weekdays             75461.9880
#         weekends             35106.7185
# Name: Total, dtype: float64

# %%
sns.barplot(x="Total",y="Branch",data=df,estimator=sum,hue="weekdays/weekends")
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Branch'>

# %%
in A branch

# %% [markdown]
# ## find weekend and weekday sale of each month

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date                Time      Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2023-05-19 13:08:00      Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2023-05-19 10:29:00         Cash
# 2         7  16.2155  340.5255 2019-03-03 2023-05-19 13:23:00  Credit card
# 3         8  23.2880  489.0480 2019-01-27 2023-05-19 20:33:00      Ewallet
# 4         7  30.2085  634.3785 2019-02-08 2023-05-19 10:37:00      Ewallet
#
# ...

# %%
df.groupby(["month_name","weekdays/weekends"])["Total"].agg(["sum"])
# Out:
#                                     sum
# month_name weekdays/weekends
# February   weekdays           68332.194
#            weekends           28887.180
# January    weekdays           83841.429
#            weekends           32450.439
# March      weekdays           70214.424
#            weekends           39241.083

# %%
sns.barplot(x="Total",y="month_name",data=df,estimator=sum,hue="weekdays/weekends")
# Out:
# <AxesSubplot:xlabel='Total', ylabel='month_name'>

# %% [markdown]
# ## find out the total weekday and weekend sell of all each branch of each month

# %%
df_a=df[df["Branch"]=="A"]
df_b=df[df["Branch"]=="B"]
df_c=df[df["Branch"]=="C"]

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
sns.barplot(x="month_name",y="Total",data=df_a,hue="weekdays/weekends")

plt.subplot(1,3,2)
sns.barplot(x="month_name",y="Total",data=df_b,hue="weekdays/weekends")

plt.subplot(1,3,3)
sns.barplot(x="month_name",y="Total",data=df_c,hue="weekdays/weekends");

# %%
#plt.figure(figsize=(8,5))
#plt.subplot(1,2,1)
#sns.barplot(x="Branch",y="Total",data=df,estimator=sum,hue="weekdays/weekends")
#plt.title("weekday/weekend sale branch wise ")
#plt.subplot(1,2,2)
sns.barplot(x="month_name",y="Total",data=df,estimator=sum,hue="weekdays/weekends")
plt.title("weekday/weekend sale month" )
# Out:
# Text(0.5, 1.0, 'weekday/weekend sale month')

# %%
sns.barplot(x="Total",y="month_name",data=df,estimator=sum,hue="weekdays/weekends");

# %% [markdown]
# ## find out the peak day

# %%
sns.countplot(x="day_name",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# ## find the hot selling day

# %%
sns.barplot(x="day_name",y="Total",data=df,estimator=sum)
plt.xticks(rotation=90);

# %%
sns.barplot(x="day_name",y="Total",data=df,estimator=sum)
plt.xticks(rotation=90);

# %% [markdown]
# ## find the hot selling day of each branch

# %%
df.groupby(["Branch","day_name"])["Total"].agg(["sum"])
# Out:
#                          sum
# Branch day_name
# A      Friday     14543.8650
#        Monday     14239.0605
#        Saturday   16765.4130
#        Sunday     17006.8185
#        Thursday   15422.2740
#        Tuesday    14955.2130
#        Wednesday  13267.7265
# B      Friday     14417.7600
#        Monday     12734.7045
#        Saturday   21284.4240
#        Sunday     10415.3280
#        Thursday   15778.6230
#        Tuesday    18859.2390
#        Wednesday  12707.5935
# C      Friday     14964.7155
#        Monday     10925.3130
#        Saturday   18070.9725
#        Sunday     17035.7460
#        Thursday   14148.3510
#        Tuesday    17667.7935
#        Wednesday  17755.8150

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Branch",y="Total",data=df,hue="day_name")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %% [markdown]
# ## visiting trend of the customer in each month

# %%
df_a_jan=df_a[df_a["month_name"]=="January"]
df_a_feb=df_a[df_a["month_name"]=="Feburary"]
df_a_march=df_a[df_a["month_name"]=="March"]

# %%
df_a_jan["Date"]
# Out:
# 0     2019-01-05
# 3     2019-01-27
# 8     2019-01-10
# 17    2019-01-01
# 18    2019-01-21
#          ...
# 942   2019-01-19
# 945   2019-01-05
# 955   2019-01-06
# 967   2019-01-13
# 981   2019-01-23
# Name: Date, Length: 119, dtype: datetime64[ns]

# %%
plt.subplot(1,3,1)
plt.hist(df_a_jan["Date"],edgecolor="black")
plt.title("visiting jan data")
plt.subplot(1,3,2)
plt.hist(df_a_feb["Date"],edgecolor="black")
plt.title("feb data")
plt.subplot(1,3,3)
plt.hist(df_a_march["Date"],edgecolor="black")
plt.title("march data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15480\1411752345.py in <module>
#       1 plt.subplot(1,3,1)
#       2 plt.hist(df_a_jan["Date"],edgecolor="black")
# ----> 3 plt.title("jan data")
#       4 plt.subplot(1,3,2)
#       5 plt.hist(df_a_feb["Date"],edgecolor="black")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## find the most populated/demanding product of the company

# %%
sns.countplot(x="Product line",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# ## which product led to high business

# %%
sns.barplot(x="Product line",y="Total",data=df,estimator=sum)
plt.xticks(rotation=90);

# %%
df["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
plt.pie(x=df["Product line"].value_counts().values,labels=df["Product line"].value_counts().index,autopct="%.2f%%");

# %% [markdown]
# ## find out the peak time

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="hour",y="Quantity",data=df,ci=None)
plt.title("product sale per hour",fontsize=20)
plt.xlabel("Time of the day",fontsize=20)
plt.xticks(df["hour"].unique())
plt.ylabel("Quantity of sale ",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15480\2171900118.py in <module>
#       1 plt.figure(figsize=(10,5))
#       2 sns.lineplot(x="hour",y="Quantity",data=df,ci=None)
# ----> 3 plt.title("product sale per hour",fontsize=20)
#       4 plt.xlabel("Time of the day",fontsize=20)
#       5 plt.xticks(df["hour"].unique())
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="hour",y="Quantity",data=df,ci=None,hue="Product line")
plt.title("product sale per hour",fontsize=20)
plt.xlabel("Time of the day",fontsize=20)
plt.xticks(df["hour"].unique())
plt.ylabel("Quantity of sale ",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15480\404543270.py in <module>
#       1 plt.figure(figsize=(10,5))
#       2 sns.lineplot(x="hour",y="Quantity",data=df,ci=None,hue="Product line")
# ----> 3 plt.title("product sale per hour",fontsize=20)
#       4 plt.xlabel("Time of the day",fontsize=20)
#       5 plt.xticks(df["hour"].unique())
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## most populated product of each branch

# %%
sns.countplot(x="Branch",data=df,hue="Product line")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# ## find the most populated product of each month at each branch

# %%
df.groupby(["Branch","month_name"])["Product line"].value_counts().sort_values(ascending=False)
# Out:
# Branch  month_name  Product line
# A       January     Home and lifestyle        27
#         March       Home and lifestyle        25
# C       February    Food and beverages        24
# A       January     Sports and travel         24
# B       February    Fashion accessories       24
# C       March       Electronic accessories    23
# B       January     Sports and travel         23
# C       January     Fashion accessories       23
# A       March       Health and beauty         23
# C       January     Sports and travel         23
# B       March       Home and lifestyle        22
# C       March       Fashion accessories       22
#         January     Food and beverages        22
# A       March       Food and beverages        22
#                     Sports and travel         21
# B       January     Fashion accessories       21
# A       February    Food and beverages        21
# B       March       Health and beauty         21
# ...

# %% [markdown]
# ## find the monthly sale of each  product

# %%
sns.barplot(x="Product line",y="Total",data=df,hue="month_name")
plt.xticks(rotation=90);

# %% [markdown]
# ## find the total number of customer

# %%
sns.countplot(x="Gender",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.barplot(x="Branch",y="Total",data=df,estimator=sum)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2]), [Text(0, 0, 'A'), Text(1, 0, 'C'), Text(2, 0, 'B')])

# %% [markdown]
# ## find out the peak time

# %%
## most populated product of eac branch

# %%
sns.countplot(x="Branch",data=df,hue="Product line")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %% [markdown]
# ## how many were member ship and non member ship male or femlae

# %%
sns.countplot(x="Customer type",data=df,hue="Gender")
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %% [markdown]
# ## which customer type lead to more business

# %%
sns.barplot(x="Customer type",y="Total",data=df,estimator=sum);

# %%
sns.barplot(x="Customer type",y="Total",data=df,estimator=sum,hue="month_name");

# %%
############################################

# %% [markdown]
# ## how many member or normal customer of each branch

# %%
sns.countplot(x="Branch",data=df,hue="Customer type");

# %%
branch wise sale of each customer

# %%
sns.barplot(x="Branch",y="Total",data=df,hue="Customer type",estimator=sum);

# %%
## find the peak time of cutomers visit at supermarket

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date                Time  \
# ...

# %%
sns.countplot(x="hour",data=df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
peak hour

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="Branch",data=df,hue="hour") # hexadecimal code for color
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
## how many products was sold on at each branch

# %%
df.groupby(["Branch","Product line"])["Quantity"].agg([sum])
# Out:
#                                sum
# Branch Product line
# A      Electronic accessories  322
#        Fashion accessories     263
#        Food and beverages      313
#        Health and beauty       257
#        Home and lifestyle      371
#        Sports and travel       333
# B      Electronic accessories  316
#        Fashion accessories     297
#        Food and beverages      270
#        Health and beauty       320
#        Home and lifestyle      295
#        Sports and travel       322
# C      Electronic accessories  333
#        Fashion accessories     342
#        Food and beverages      369
#        Health and beauty       277
#        Home and lifestyle      245
#        Sports and travel       265

# %%
find highest,lowest and average

# %%
how many of the customer given 10 rating

# %%
how many of give rating greater than average

# %%
## max,min and average rating by customers at each branch

# %%
## find out the product which have been like by most of the customer

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date  ...    cogs  \
# 0         74.69         7  26.1415   548.9715 2019-01-05  ...  522.83
# ...

# %%
## of which mode of the customer paid the bill

# %%
sns.countplot(x="Payment",data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x="Branch",data=df,hue="Payment")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
sns.barplot(x="Branch",y="Total",data=df,hue="Payment",estimator=sum)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>
